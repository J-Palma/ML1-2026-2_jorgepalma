# %% [markdown]
# # TP 1 - Notebook de prueba

# %% [markdown]
# Notebook de prueba para el Trabajo Practico 1.

# %%
print("Hola desde TP1!"
# Out:
# Versión del Intérprete Python: 3.12.13 | packaged by Anaconda, Inc. | (main, Jul  9 2026, 14:26:47) [MSC v.1942 64 bit (AMD64)]
# Versión de NumPy: 2.5.2
# Versión de Pandas: 3.0.5
# Versión de Scikit-learn: 1.9.0
# ¡El Workspace en Antigravity IDE y el entorno virtual se ejecutan correctamente!
